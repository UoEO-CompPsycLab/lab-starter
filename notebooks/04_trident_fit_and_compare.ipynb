# %% [markdown]
# # Trident-G fit + compare\n\nFit baseline vs Trident toy learner and write results to `results/`.

# %%
# TODO: load data/generated/trident/theta_timeseries.csv\n# TODO: fit models and write tables/figures
