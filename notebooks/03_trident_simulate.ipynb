# %% [markdown]
# # Trident-G simulation\n\nThis notebook will generate change-point time-series data and save to `data/generated/trident/`.

# %%
# TODO: implement simulation\n# Save: data/generated/trident/theta_timeseries.csv
